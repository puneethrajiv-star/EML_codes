# %% [markdown]
# #Implement Naïve Bayesian classifier for a sample training data set stored as a CSV file. Compute the accuracy of classifier, Considering few test data sets.

# %%
# ==========================================
# Naïve Bayes Classifier Implementation
# ==========================================

# Import required libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# ------------------------------------------
# Step 1: Load the dataset
# ------------------------------------------
data = pd.read_csv('data.csv')

# ------------------------------------------
# Step 2: Separate input features and target
# ------------------------------------------
# Assume last column is the class label
X = data.iloc[:, :-1]
Y = data.iloc[:, -1]

# ------------------------------------------
# Step 3: Encode categorical features
# ------------------------------------------
# Naïve Bayes works with numerical data
le = LabelEncoder()

for col in X.columns:
    X[col] = le.fit_transform(X[col])

# Encode target variable
Y = le.fit_transform(Y)

# ------------------------------------------
# Step 4: Split data into training and test sets
# ------------------------------------------
X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.3, random_state=42
)

# ------------------------------------------
# Step 5: Train Naïve Bayes classifier
# ------------------------------------------
nb = GaussianNB()
nb.fit(X_train, Y_train)

# ------------------------------------------
# Step 6: Predict on test data
# ------------------------------------------
Y_pred = nb.predict(X_test)

# ------------------------------------------
# Step 7: Compute accuracy of the classifier
# ------------------------------------------
accuracy = accuracy_score(Y_test, Y_pred)
print("Accuracy of Naïve Bayes Classifier:", accuracy)
# Out:
# Accuracy of Naïve Bayes Classifier: 0.772972972972973
